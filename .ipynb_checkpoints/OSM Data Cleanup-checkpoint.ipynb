# %%
import xml.etree.ElementTree as ET
from sets import Set
import re
import parsedatetime
import usaddress
import urllib2
from BeautifulSoup import BeautifulSoup
from pymongo import MongoClient
import heapq

# %%
### Utility Functions ###
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def is_opening_hours(elem):
    return (elem.attrib['k'] == "opening_hours")

# %%
### Exploring the Data: Street Names ###
count = 0
for event, elem in ET.iterparse('los-angeles_california.osm', events=("start",)):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if is_street_name(tag):
                print ET.tostring(elem, 'utf-8')
                count += 1
    if count > 10:
        break
    elem.clear()
# Out:
# <node changeset="29169942" id="49783403" lat="33.3977365" lon="-117.1701879" timestamp="2015-03-01T04:53:03Z" uid="1330847" user="TheDutchMan13" version="4">
# 		<tag k="source" v="SanGIS Addresses Public Domain (http://www.sangis.org/)" />
# 		<tag k="addr:city" v="San Diego" />
# 		<tag k="is_in:city" v="San Diego" />
# 		<tag k="addr:street" v="Rainbow Glen Rd" />
# 		<tag k="is_in:state" v="California" />
# 		<tag k="addr:country" v="US" />
# 		<tag k="addr:postcode" v="92028" />
# 		<tag k="is_in:country" v="United States of America" />
# 		<tag k="addr:housenumber" v="2319" />
# 		<tag k="is_in:state_code" v="CA" />
# 		<tag k="is_in:country_code" v="US" />
# 	</node>
#
# <node changeset="9791354" id="97044219" lat="34.0573651" lon="-117.1907772" timestamp="2011-11-10T19:17:52Z" uid="492980" user="woodence" version="7">
# 		<tag k="name" v="Circle K &amp; Minimart" />
# 		<tag k="amenity" v="fuel" />
# 		<tag k="operator" v="Circle K" />
# 		<tag k="addr:street" v="W Redlands Blvd" />
# 		<tag k="description" v="Average fuel prices, best prices on fountain drinks on area. Friendly staff" />
# 		<tag k="opening_hours" v="24/7" />
# 		<tag k="addr:housenumber" v="765" />
# 	</node>
# <node changeset="13829232" id="98640668" lat="34.0563345" lon="-117.186232" timestamp="2012-11-11T07:23:57Z" uid="740747" user="Craig Williams" version="4">
# 		<tag k="name" v="ḾU" />
# 		<tag k="amenity" v="restaurant" />
# 		<tag k="cuisine" v="thai" />
# 		<tag k="website" v="http://www.mumartini.com/" />
# 		<tag k="old_name" v="Rama Garden" />
# 		<tag k="addr:street" v="W. State St." />
# 		<tag k="addr:postcode" v="92373" />
# 		<tag k="addr:housenumber" v="309" />
# 	</node>
#
# <node changeset="31650557" id="123774379" lat="34.2120141" lon="-118.2188064" timestamp="2015-06-01T23:06:51Z" uid="2498363" user="paztownsend" version="5">
# 		<tag k="name" v="YMCA of the Foothills" />
# 		<tag k="amenity" v="community_centre" />
# 		<tag k="operator" v="YMCA" />
# 		<tag k="addr:city" v="La Cañada Flintridge" />
# 		<tag k="addr:state" v="CA" />
# 		<tag k="addr:street" v="Foothill Boulevard" />
# 		<tag k="addr:postcode" v="91011" />
# 		<tag k="addr:housenumber" v="1930" />
# 	</node>
# <node changeset="15418611" id="256884236" lat="34.0834064" lon="-118.3852227" timestamp="2013-03-19T18:57:32Z" uid="290680" user="wheelmap_visitor" version="6">
# 		<tag k="gay" v="yes" />
# 		<tag k="name" v="The Abbey" />
# 		<tag k="amenity" v="bar" />
# 		<tag k="website" v="http://abbeyfoodandbar.com" />
# 		<tag k="addr:city" v="West Hollywood" />
# 		<tag k="wheelchair" v="yes" />
# 		<tag k="addr:street" v="North Robertson Blvd." />
# 		<tag k="addr:postcode" v="90069" />
# 		<tag k="contact:phone" v="+1 310 289 8410" />
# 		<tag k="addr:housenumber" v="692" />
# 	</node>
# <node changeset="7835812" id="268376953" lat="34.0947553" lon="-118.0999008" timestamp="2011-04-11T18:24:26Z" uid="70696" user="xybot" version="6">
# 		<tag k="name" v="City Of San Gabriel Police Department" />
# 		<tag k="amenity" v="police" />
# 		<tag k="addr:city" v="San Gabriel" />
# 		<tag k="addr:full" v="625 Del Mar Avenue San Gabriel Ca 91776 United States" />
# 		<tag k="addr:street" v="Del Mar Avenue" />
# 		<tag k="addr:country" v="US" />
# 		<tag k="addr:postcode" v="91776" />
# 		<tag k="addr:housenumber" v="625" />
# 	</node>
# <node changeset="3293054" id="281222332" lat="33.7369656" lon="-117.9431568" timestamp="2009-12-05T03:26:28Z" uid="36038" user="DialH" version="3">
# 		<tag k="addr:street" v="Kedge Ave" />
# 		<tag k="addr:housenumber" v="10661" />
# 	</node>
# <node changeset="3293054" id="281222470" lat="33.7369513" lon="-117.9429593" timestamp="2009-12-05T03:26:28Z" uid="36038" user="DialH" version="3">
# 		<tag k="addr:street" v="Kedge Ave" />
# 		<tag k="addr:housenumber" v="10671" />
# 	</node>
#
# <node changeset="3293054" id="281222596" lat="33.7369729" lon="-117.9425644" timestamp="2009-12-05T03:26:27Z" uid="36038" user="DialH" version="3">
# 		<tag k="addr:street" v="Kedge Ave" />
# 		<tag k="addr:housenumber" v="10691" />
# 	</node>
#
# <node changeset="3293054" id="281222682" lat="33.7369729" lon="-117.9423584" timestamp="2009-12-05T03:26:26Z" uid="36038" user="DialH" version="3">
# 		<tag k="addr:street" v="Kedge Ave" />
# 		<tag k="addr:housenumber" v="10701" />
# 	</node>
#
# <node changeset="3293054" id="281222780" lat="33.7369729" lon="-117.942144" timestamp="2009-12-05T03:26:26Z" uid="36038" user="DialH" version="3">
# 		<tag k="addr:street" v="Kedge Ave" />
# 		<tag k="addr:housenumber" v="10711" />
# 	</node>

# %%
#This code yields a bunch of bad data for street types
streets = Set()
for event, elem in ET.iterparse('los-angeles_california.osm', events=("start",)):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if is_street_name(tag):
                streets.add(tag.get('v').split(" ")[-1])
    elem.clear()
streets
# Out:
# Set(['', 'Rosslyn', 'Rossmore', 'Perla', 'Sun', 'Zephyr', 'Viajante', 'Bumblebee', 'Trowel', 'Heights', 'Capri', 'Moor', 'Shepard', 'Libre', 'Leaf', 'Pacifico', 'Prone', 'Montecilo', 'Thornapple', 'Columbia', 'Pretzels', 'Vinci', 'Kimbal', 'Sideways', 'Nog', 'Fremont', 'Alder', 'Langford', 'Solita', 'Encinal', 'madera', 'Arboles', 'Western', 'Waynesboro', 'PacSun', 'Odyssey', 'Arroyo', 'Larkfield', 'Salk', '7', 'Montrose', 'Centralia', 'Valle', 'Limar', 'Scenica', 'Saddlehorn', 'Photinia', 'Cir', 'Elmdale', 'Poppy', 'Barrel', 'Moon', 'Medford', 'Arborwood', 'Parker', '39.84', 'Marketview', 'Canoe', 'Pier', 'Canon', 'Pacifica', 'Wycliffe', 'Seabluff', 'Int', 'Gainesmill', 'Garnet', 'Sagecrest', 'Cienega', 'Endeavor', 'Gl', 'Canterra', 'Allium', 'Pauling', 'Gentry', 'Aven', 'Antietam', 'Pointe', 'Midsummer', 'Flatiron', 'Buckwood', 'Alamos', 'BLVD', 'Lago', 'Cerise', 'Barcelona', 'Carolwood', 'Circle', 'East', 'Legacy', 'Townsend', 'Raton', 'Eastway', 'Nickel', 'Ctr.', 'Williams', 'Halsted', 'Alameda', 'Herringbone', 'Visionary', 'Crockett', 'Aguacate', 'access', 'Oro', 'Olivia', 'Vuelta', 'Toledo', 'Cuesta', 'ct.', 'Francis', 'Spur', 'Verano', 'Steinway', 'Md', 'Ashdale', 'Ave.', 'Padre', 'Unidos', 'Clover', '443', 'Light', 'McClennan', 'Church', 'Clarion', 'Burbank', 'Marblehead', 'Waterleaf', 'Shore', 'Bl.', 'Green', 'Horizonte', 'Cloister', '100', 'Loganberry', 'Settlers', '54.6', 'Plata', 'Hallmark', '38', 'Clark', 'Tequila', '#1216', 'Saybrook', 'Hardy', 'Ascot', 'Clary', 'Rexford', 'Corto', 'Shelbourne', 'Wonderland', 'Candleglow', 'Northstar', 'Deerpath', 'Oldfield', 'Canal', 'Jameson', 'Mecklenberg', 'St.', 'Gazebo', 'Paz', 'Pepperoot', 'Providence', 'Pasadena', 'Cardinal', 'Codorniz', 'Rita', 'Columbus', 'Star', 'Greenbriar', 'Vallecito', 'Glass', 'Planicie', 'Pear', 'Diagonal', 'Alegre', 'Windsong', 'Mia', 'Vernon', 'Honeyflower', 'Alondra', 'Arboretum', '6', 'Blvd.', 'Fl', 'Thibault', 'Iris', 'Lane', '39', 'Chianti', 'Sq', 'Cagney', 'Roio', 'Forestwood', 'St', 'Lankershim', 'Tierra', 'Estrellas', 'Taylor', 'Ashfield', 'Str', 'Genoa', 'Homecoming', 'Marketplace', '#104', 'Triana', 'Peony', 'Cornwallis', 'Brookdale', 'Heirloom', 'Sage', 'Esplanade', 'Hollow', 'Westgate', 'Elkwood', 'Birmingham', 'Bianco', '61.8', 'Gianni-Turco', 'Nicole', 'Elderwood', 'Talisman', 'Heather', 'Bonita', 'La', 'Sepulveda', 'Vine', 'Calhoun', 'Millgrove', 'Laceflower', 'Smallwheel', 'Forbes', 'Rawhide', 'Lp', 'Nord', 'blvd', 'Prado', 'Fieldwood', 'Canonero', 'Kennard', 'Paramount', 'Lindberg', u'246-0756', 'Cipres', 'McLaren', 'Camino', 'Rossmoor', 'Ranchland', 'Oasis', 'Middleton', 'Ovation', 'Invierno', 'Furrow', 'A', 'Sarabande', 'Mainstreet', 'Caballeros', 'Cumbres', 'Oakville', 'Newington', 'Ctf', 'Robles', 'Summerfield', 'Daisy', 'Grassland', 'court', '#106', '#102', 'View', 'Churchill', 'US395', 'Cedars', 'Denim', 'Highlander', 'Poplarwood', 'Partricio', 'Breeze', 'Jackrabbit', 'Campana', 'Chime', 'Florera', 'Midvale', 'Visions', 'Fernando', 'Follyhatch', 'Plumbago', 'Rinaldi', 'Fernbank', 'Capistrano', 'Brook', 'Southbrook', 'Rd', 'Pedro', '#203', 'Roxanne', '#200', 'Cantora', 'Oaks', '138', 'avenue', 'Mallorca', 'Entrada', '#208', 'Tomas', '26', '21', 'Serena', 'Keepsake', 'Pendant', 'Livia', 'Monticello', 'Cove', 'Albercon', 'Pata', 'Seaward', 'Springwater', 'Whitney', 'Baritone', 'Boda', 'Path', 'Outlet;Suite', 'Vereda', 'Nugget', 'Ladera', 'Companero', 'Sharmila', 'Loma', 'Abeto', 'Ashwood', 'Conchita', 'Morella', 'Paperbark', 'Serpiente', 'Eureka', 'Rociada', 'Icon', 'Cam', 'Brookhaven', 'Vientos', 'Fawn', 'Devonshire', 'Indio', 'Kentworth', 'Fragrances', 'Lace', 'Habitat', 'Corozal', 'T250', 'Fairgrove', 'Amapola', 'Bancroft', 'Busca', 'Calderon', 'Timberland', 'Lomas', 'Velvetleaf', 'Rainbow', 'Figueroa', 'End', 'Contessa', 'Rose', 'Luz', 'Treasure', 'Rosa', 'Poniente', 'Cipresso', 'Piemonte', 'Alley', '395', 'Appomattox', 'Latitude', 'Manantial', 'Rosemead', 'Tweed', 'Sedona', 'Ross', 'Moorsview', 'Mapleton', '3rd', 'Hathawa ...

# %%
#Trying a more sophisticated approach that uses natural language processing module usaddress
#https://github.com/datamade/usaddress
streets = Set()
for event, elem in ET.iterparse('los-angeles_california.osm', events=("start",)):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if is_street_name(tag):
                try:
                    streets.add(str(next((st for st, comp in usaddress.parse(tag.get('v')) if comp == "StreetNamePostType"))))
                except:
                    continue
    elem.clear()
streets
# Out:
# Set(['Glen', 'Boulevard', 'Court', 'Ln', 'St.', 'Tr', 'Rd', 'blvd', 'Tl', 'street', 'Way', 'Dr.', 'BLVD', 'Gate', 'Circle', 'Te', 'avenue', 'Pl', 'Avenue,', 'Rd.', 'court', 'Wa', '&', 'Park', 'Cove', 'Boulevard;', 'Trail', 'Highway', 'way', 'Hwy', 'Boulevard,', 'ct.', 'Dr', 'Tt', 'Wy', 'PM', 'Lane', 'Plaza', 'Ave.', 'Trl', 'Ave,', 'Avenue.', 'Blvd:', 'Drive', 'Pkwy.', 'St', 'Cir', 'Ctf', 'Place', 'WAY', 'Parkway', 'Pkwy', 'Off', 'Blvd,', 'Road', 'Blvd.', 'ave', 'Avenue;', 'ST', 'Drive,', 'Street', 'str', 'Av', 'Blvd', 'Ave', 'Ic', 'Avenue', 'road', 'Ct'])

# %%
#The file `C1 Street Suffix Abbreviations.html` is the html downloaded from the webpage at http://pe.usps.gov/text/pub28/28apc_002.htm 
#The main table with all of the street suffix abbreviations and variations has an id of ep533076
#Its body is structured as follows, and the algorithm below uses this structure 
#to make {abbrev: full_name} pairs for each abbreviation, including the standard one if
#it's not already included in the middle column
#-------------------------------------------
#| Full Name | Abbrev #1 | Standard Abbrev |
#|  <empty>  | Abbrev #2 |     <empty>     |
#|  <empty>  | Abbrev #3 |     <empty>     |
#|  <empty>  | Abbrev #4 |     <empty>     |
#       ...        etc         ...
#-------------------------------------------
streetConversionMap = {}
soup = BeautifulSoup(open("C1 Street Suffix Abbreviations.html"))
table = soup.find('table', attrs={'id': 'ep533076'})
rows = table.findAll('tr')
numberOfRowsToSkip = 1
fullName = "thisShouldBeReassignedBeforeUseInStreetConversionMap"
for tr in rows:
    if numberOfRowsToSkip > 0:
        numberOfRowsToSkip -= 1
        continue
    cols = tr.findAll('td')
    if len(cols) == 3: #if there are three cells, then the first one is the Full Name
        fullName = str(cols[0].find(text=True)).strip()
        cols = cols[1:]
    for td in cols:
        abbreviation = str(td.find(text=True)).strip()
        if (abbreviation != '' and abbreviation != fullName):
            streetConversionMap[abbreviation] = fullName
            
streetConversionMap
# Out:
# {'ALLEE': 'ALLEY',
#  'ALLY': 'ALLEY',
#  'ALY': 'ALLEY',
#  'ANNEX': 'ANEX',
#  'ANNX': 'ANEX',
#  'ANX': 'ANEX',
#  'ARC': 'ARCADE',
#  'AV': 'AVENUE',
#  'AVE': 'AVENUE',
#  'AVEN': 'AVENUE',
#  'AVENU': 'AVENUE',
#  'AVN': 'AVENUE',
#  'AVNUE': 'AVENUE',
#  'BAYOO': 'BAYOU',
#  'BCH': 'BEACH',
#  'BG': 'BURG',
#  'BGS': 'BURGS',
#  'BLF': 'BLUFF',
#  'BLFS': 'BLUFFS',
#  'BLUF': 'BLUFF',
#  'BLVD': 'BOULEVARD',
#  'BND': 'BEND',
#  'BOT': 'BOTTOM',
#  'BOTTM': 'BOTTOM',
#  'BOUL': 'BOULEVARD',
#  'BOULV': 'BOULEVARD',
#  'BR': 'BRANCH',
#  'BRDGE': 'BRIDGE',
#  'BRG': 'BRIDGE',
#  'BRK': 'BROOK',
#  'BRKS': 'BROOKS',
#  'BRNCH': 'BRANCH',
#  'BTM': 'BOTTOM',
#  'BYP': 'BYPASS',
#  'BYPA': 'BYPASS',
#  'BYPAS': 'BYPASS',
#  'BYPS': 'BYPASS',
#  'CANYN': 'CANYON',
#  'CAUSWA': 'CAUSEWAY',
#  'CEN': 'CENTER',
#  'CENT': 'CENTER',
#  'CENTR': 'CENTER',
#  'CENTRE': 'CENTER',
#  'CIR': 'CIRCLE',
#  'CIRC': 'CIRCLE',
#  'CIRCL': 'CIRCLE',
#  'CIRS': 'CIRCLES',
#  'CLB': 'CLUB',
#  'CLF': 'CLIFF',
#  'CLFS': 'CLIFFS',
#  'CMN': 'COMMON',
#  'CMNS': 'COMMONS',
#  'CMP': 'CAMP',
#  'CNTER': 'CENTER',
#  'CNTR': 'CENTER',
#  'CNYN': 'CANYON',
#  'COR': 'CORNER',
#  'CORS': 'CORNERS',
#  'CP': 'CAMP',
#  'CPE': 'CAPE',
#  'CRCL': 'CIRCLE',
#  'CRCLE': 'CIRCLE',
#  'CRES': 'CRESCENT',
#  'CRK': 'CREEK',
#  'CRSE': 'COURSE',
#  'CRSENT': 'CRESCENT',
#  'CRSNT': 'CRESCENT',
#  'CRSSNG': 'CROSSING',
#  'CRST': 'CREST',
#  'CSWY': 'CAUSEWAY',
#  'CT': 'COURT',
#  'CTR': 'CENTER',
#  'CTRS': 'CENTERS',
#  'CTS': 'COURTS',
#  'CURV': 'CURVE',
#  'CV': 'COVE',
#  'CVS': 'COVES',
#  'CYN': 'CANYON',
#  'DIV': 'DIVIDE',
#  'DL': 'DALE',
#  'DM': 'DAM',
#  'DR': 'DRIVE',
#  'DRIV': 'DRIVE',
#  'DRS': 'DRIVES',
#  'DRV': 'DRIVE',
#  'DV': 'DIVIDE',
#  'DVD': 'DIVIDE',
#  'EST': 'ESTATE',
#  'ESTS': 'ESTATES',
#  'EXP': 'EXPRESSWAY',
#  'EXPR': 'EXPRESSWAY',
#  'EXPRESS': 'EXPRESSWAY',
#  'EXPW': 'EXPRESSWAY',
#  'EXPY': 'EXPRESSWAY',
#  'EXT': 'EXTENSION',
#  'EXTN': 'EXTENSION',
#  'EXTNSN': 'EXTENSION',
#  'EXTS': 'EXTENSIONS',
#  'FLD': 'FIELD',
#  'FLDS': 'FIELDS',
#  'FLS': 'FALLS',
#  'FLT': 'FLAT',
#  'FLTS': 'FLATS',
#  'FORESTS': 'FOREST',
#  'FORG': 'FORGE',
#  'FRD': 'FORD',
#  'FRDS': 'FORDS',
#  'FREEWY': 'FREEWAY',
#  'FRG': 'FORGE',
#  'FRGS': 'FORGES',
#  'FRK': 'FORK',
#  'FRKS': 'FORKS',
#  'FRRY': 'FERRY',
#  'FRST': 'FOREST',
#  'FRT': 'FORT',
#  'FRWAY': 'FREEWAY',
#  'FRWY': 'FREEWAY',
#  'FRY': 'FERRY',
#  'FT': 'FORT',
#  'FWY': 'FREEWAY',
#  'GARDN': 'GARDEN',
#  'GATEWY': 'GATEWAY',
#  'GATWAY': 'GATEWAY',
#  'GDN': 'GARDEN',
#  'GDNS': 'GARDENS',
#  'GLN': 'GLEN',
#  'GLNS': 'GLENS',
#  'GRDEN': 'GARDEN',
#  'GRDN': 'GARDEN',
#  'GRDNS': 'GARDENS',
#  'GRN': 'GREEN',
#  'GRNS': 'GREENS',
#  'GROV': 'GROVE',
#  'GRV': 'GROVE',
#  'GRVS': 'GROVES',
#  'GTWAY': 'GATEWAY',
#  'GTWY': 'GATEWAY',
#  'HARB': 'HARBOR',
#  'HARBR': 'HARBOR',
#  'HBR': 'HARBOR',
#  'HBRS': 'HARBORS',
#  'HIGHWY': 'HIGHWAY',
#  'HIWAY': 'HIGHWAY',
#  'HIWY': 'HIGHWAY',
#  'HL': 'HILL',
#  'HLLW': 'HOLLOW',
#  'HLS': 'HILLS',
#  'HOLLOWS': 'HOLLOW',
#  'HOLW': 'HOLLOW',
#  'HOLWS': 'HOLLOW',
#  'HRBOR': 'HARBOR',
#  'HT': 'HEIGHTS',
#  'HTS': 'HEIGHTS',
#  'HVN': 'HAVEN',
#  'HWAY': 'HIGHWAY',
#  'HWY': 'HIGHWAY',
#  'INLT': 'INLET',
#  'IS': 'ISLAND',
#  'ISLES': 'ISLE',
#  'ISLND': 'ISLAND',
#  'ISLNDS': 'ISLANDS',
#  'ISS': 'ISLANDS',
#  'JCT': 'JUNCTION',
#  'JCTION': 'JUNCTION',
#  'JCTN': 'JUNCTION',
#  'JCTNS': 'JUNCTIONS',
#  'JCTS': 'JUNCTIONS',
#  'JUNCTN': 'JUNCTION',
#  'JUNCTON': 'JUNCTION',
#  'KNL': 'KNOLL',
#  'KNLS': 'KNOLLS',
#  'KNOL': 'KNOLL',
#  'KY': 'KEY',
#  'KYS': 'KEYS',
#  'LCK': 'LOCK',
#  'LCKS': 'LOCKS',
#  'LDG': 'LODGE',
#  'LDGE': 'LODGE',
#  'LF': 'LOAF',
#  'LGT': 'LIGHT',
#  'LGTS': 'LIGHTS',
#  'LK': 'LAKE',
#  'LKS': 'LAKES',
#  'LN': 'LANE',
#  'LNDG': 'LANDING',
#  'LNDNG': 'LANDING',
#  'LODG': 'LODGE',
#  'LOOPS': 'LOOP',
#  'MDW': 'MEADOWS',
#  'MDWS': 'MEADOWS',
#  'MEDOWS': 'MEADOWS',
#  'MISSN': 'MISSION',
#  'ML': 'MILL',
#  'MLS': 'MILLS',
#  'MNR': 'MANOR',
#  'MNRS': 'MANORS',
#  'MNT': 'MOUNT',
#  'MNTAIN': 'MOUNTAIN',
#  'MNTN': 'MOUNTAIN',
#  'MNTNS': 'MOUNTAINS',
#  'MOUNTIN': 'MOUNTAIN',
#  'MSN': 'MISSION',
#  'MSSN': 'MISSION',
#  'MT': 'MOUNT',
#  'MTIN': 'MOUNTAIN',
#  'MTN': 'MOUNTAIN',
#  'MTNS': 'MOUNTAINS',
#  'MTWY': 'MOTORWAY',
#  'NCK': 'NECK',
#  'OPAS': 'OVERPASS',
#  'ORCH': 'ORCHARD',
#  'ORCHRD': 'ORCHARD',
#  'OVL': 'OVAL',
#  'PARK': 'PARKS',
#  'PARKWY': 'PARKWAY',
#  'PATHS': 'PATH',
#  'PIKES': 'PIKE',
#  'PKWAY': 'PARKWAY',
#  'PKWY': 'PARKWAYS',
#  'PKWYS': 'PARKWAYS',
#  'PKY': 'PARKWAY',
#  'PL': 'PLACE',
#  'PLN': 'PLAIN',
#  'PLNS': 'PLAINS',
#  'PLZ': 'PLAZA',
#  'PLZA': 'PLAZA',
#  'PNE': 'PINE',
#  'PNES': 'PINES',
#  'PR': 'PRAIRIE',
#  'PRK': 'PARK',
#  'PRR': 'PRAIRIE',
#  'PRT': 'PORT',
#  'PRTS': 'PORTS',
#  'PSGE': 'PASSAGE',
#  'PT': 'POINT',
#  'PTS': 'POINTS',
#  'RAD': 'RADIAL',
#  'RADIEL': 'RADIAL',
#  'RADL': 'RADIAL',
#  'RANCHES': 'RANCH',
#  'RD': 'ROAD',
#  'RDG': 'RIDGE',
#  'RDGE': 'RIDGE',
#  'RDGS': 'RIDGES',
#  'RDS': 'ROADS',
#  'RIV': 'RIVER',
#  'RIVR': 'RIVER',
#  'RNCH': 'RANCH',
#  'RNCHS': 'RANCH',
#  'RPD': 'RAPID',
#  'RPDS': 'RAPIDS',
#  'RST': 'REST',
#  'RTE': 'ROUTE',
#  'RVR': 'RIVER',
#  'SHL': 'SHOAL',
#  'SHLS': 'SHOALS',
#  'SHOAR': 'SHORE',
#  'SHOARS': 'SHORES',
#  'SHR': 'SHORE',
#  'SHRS': 'SHORES',
#  'SKWY': 'SKYWAY',
#  'SMT': 'SUMMIT',
#  'SPG': 'SPRING',
#  'SPGS': 'SPRINGS',
#  'SPNG': 'SPRING',
#  'SPNGS': 'SPRINGS',
#  'SPRNG': 'SPRING',
#  'SPRNGS': 'SPRINGS',
#  'SPUR': 'SPURS',
#  'SQ': 'SQUARE',
#  'SQR': 'SQUARE',
#  'SQRE': 'SQUARE',
#  'SQRS': 'SQUARES',
#  'SQS': 'SQUARES',
#  'SQU': 'SQUARE',
#  'ST': 'STREET',
#  'STA': 'STATION',
#  'STATN': 'STATION',
#  'STN': 'STATION',
#  'STR': 'STREET',
#  'STRA': 'STRAVENUE',
#  'STRAV': 'STRAVENUE',
#  'STRAVEN': 'STRAVENUE',
#  'STRAVN': 'STRAVENUE',
#  'STREME': 'STREAM',
#  'STRM': 'STREAM',
#  'STRT': 'STREET',
#  'STRVN': 'STRAVENUE',
#  'STRVNUE': 'STRAVENUE',
#  'STS': 'STREETS',
#  'SUMIT': 'SUMMIT',
#  'SUMITT': 'SUMMIT',
#  'TER': 'TERRACE',
#  'TERR': 'TERRACE',
#  'TPKE': 'TURNPIKE',
#  'TRACES': 'TRACE',
#  'TRACKS': 'TRACK',
#  'TRAILS': 'TRAIL',
#  'TRAK': 'TRACK',
#  'TRCE': 'TRACE',
#  'TRFY': 'TRAFFICWAY',
#  'TRK': 'TRACK',
#  'TRKS': 'TRACK',
#  'TRL': 'TRAIL',
#  'TRLR': 'TRAILER',
#  'TRLRS': 'TRAILER',
#  'TRLS': 'TRAIL',
#  'TRNPK': 'TURNPIKE',
#  'TRWY': 'THROUGHWAY',
#  'TUNEL': 'TUNNEL',
#  'TUNL': 'TUNNEL',
#  'TUNLS': 'TUNNEL',
#  'TUNNELS': 'TUNNEL',
#  'TUNNL': 'TUNNEL',
#  'TURNPK': 'TURNPIKE',
#  'UN': 'UNION',
#  'UNS': 'UNIONS',
#  'UPAS': 'UNDERPASS',
#  'VALLY': 'VALLEY',
#  'VDCT': 'VIADUCT',
#  'VIA': 'VIADUCT',
#  'VIADCT': 'VIADUCT',
#  'VILL': 'VILLAGE',
#  'VILLAG': 'VILLAGE',
#  'VILLG': 'VILLAGE',
#  'VILLIAGE': 'VILLAGE',
#  'VIS': 'VISTA',
#  'VIST': 'VISTA',
#  'VL': 'VILLE',
#  'VLG': 'VILLAGE',
#  'VLGS': 'VILLAGES',
#  'VLLY': 'VALLEY',
#  'VLY': 'VALLEY',
#  'VLYS': 'VALLEYS',
#  'VST': 'VISTA',
#  'VSTA': 'VISTA',
#  'VW': 'VIEW',
#  'VWS': 'VIEWS',
#  'WALK': 'WALKS',
#  'WL': 'WELL',
#  'WLS': 'WELLS',
#  'WY': 'WAY',
#  'XING': 'CROSSING',
#  'XRD': 'CROSSROAD',
#  'XRDS': 'CROSSROADS'}

# %%
#Even the post office's list of abbreviations isn't complete. Scanning the LA OSM data, I found five more
#abbreviations that I could guess the full name from.
customStreetConversionMap = {
    "TR": "TRAIL",
    "BL": "BOULEVARD",
    "TL": "TRAIL",
    "TE": "TERRACE",
    "WA": "WAY"
}
streetConversionMap.update(customStreetConversionMap)
streetConversionMap
# Out:
# {'ALLEE': 'ALLEY',
#  'ALLY': 'ALLEY',
#  'ALY': 'ALLEY',
#  'ANNEX': 'ANEX',
#  'ANNX': 'ANEX',
#  'ANX': 'ANEX',
#  'ARC': 'ARCADE',
#  'AV': 'AVENUE',
#  'AVE': 'AVENUE',
#  'AVEN': 'AVENUE',
#  'AVENU': 'AVENUE',
#  'AVN': 'AVENUE',
#  'AVNUE': 'AVENUE',
#  'BAYOO': 'BAYOU',
#  'BCH': 'BEACH',
#  'BG': 'BURG',
#  'BGS': 'BURGS',
#  'BL': 'BOULEVARD',
#  'BLF': 'BLUFF',
#  'BLFS': 'BLUFFS',
#  'BLUF': 'BLUFF',
#  'BLVD': 'BOULEVARD',
#  'BND': 'BEND',
#  'BOT': 'BOTTOM',
#  'BOTTM': 'BOTTOM',
#  'BOUL': 'BOULEVARD',
#  'BOULV': 'BOULEVARD',
#  'BR': 'BRANCH',
#  'BRDGE': 'BRIDGE',
#  'BRG': 'BRIDGE',
#  'BRK': 'BROOK',
#  'BRKS': 'BROOKS',
#  'BRNCH': 'BRANCH',
#  'BTM': 'BOTTOM',
#  'BYP': 'BYPASS',
#  'BYPA': 'BYPASS',
#  'BYPAS': 'BYPASS',
#  'BYPS': 'BYPASS',
#  'CANYN': 'CANYON',
#  'CAUSWA': 'CAUSEWAY',
#  'CEN': 'CENTER',
#  'CENT': 'CENTER',
#  'CENTR': 'CENTER',
#  'CENTRE': 'CENTER',
#  'CIR': 'CIRCLE',
#  'CIRC': 'CIRCLE',
#  'CIRCL': 'CIRCLE',
#  'CIRS': 'CIRCLES',
#  'CLB': 'CLUB',
#  'CLF': 'CLIFF',
#  'CLFS': 'CLIFFS',
#  'CMN': 'COMMON',
#  'CMNS': 'COMMONS',
#  'CMP': 'CAMP',
#  'CNTER': 'CENTER',
#  'CNTR': 'CENTER',
#  'CNYN': 'CANYON',
#  'COR': 'CORNER',
#  'CORS': 'CORNERS',
#  'CP': 'CAMP',
#  'CPE': 'CAPE',
#  'CRCL': 'CIRCLE',
#  'CRCLE': 'CIRCLE',
#  'CRES': 'CRESCENT',
#  'CRK': 'CREEK',
#  'CRSE': 'COURSE',
#  'CRSENT': 'CRESCENT',
#  'CRSNT': 'CRESCENT',
#  'CRSSNG': 'CROSSING',
#  'CRST': 'CREST',
#  'CSWY': 'CAUSEWAY',
#  'CT': 'COURT',
#  'CTR': 'CENTER',
#  'CTRS': 'CENTERS',
#  'CTS': 'COURTS',
#  'CURV': 'CURVE',
#  'CV': 'COVE',
#  'CVS': 'COVES',
#  'CYN': 'CANYON',
#  'DIV': 'DIVIDE',
#  'DL': 'DALE',
#  'DM': 'DAM',
#  'DR': 'DRIVE',
#  'DRIV': 'DRIVE',
#  'DRS': 'DRIVES',
#  'DRV': 'DRIVE',
#  'DV': 'DIVIDE',
#  'DVD': 'DIVIDE',
#  'EST': 'ESTATE',
#  'ESTS': 'ESTATES',
#  'EXP': 'EXPRESSWAY',
#  'EXPR': 'EXPRESSWAY',
#  'EXPRESS': 'EXPRESSWAY',
#  'EXPW': 'EXPRESSWAY',
#  'EXPY': 'EXPRESSWAY',
#  'EXT': 'EXTENSION',
#  'EXTN': 'EXTENSION',
#  'EXTNSN': 'EXTENSION',
#  'EXTS': 'EXTENSIONS',
#  'FLD': 'FIELD',
#  'FLDS': 'FIELDS',
#  'FLS': 'FALLS',
#  'FLT': 'FLAT',
#  'FLTS': 'FLATS',
#  'FORESTS': 'FOREST',
#  'FORG': 'FORGE',
#  'FRD': 'FORD',
#  'FRDS': 'FORDS',
#  'FREEWY': 'FREEWAY',
#  'FRG': 'FORGE',
#  'FRGS': 'FORGES',
#  'FRK': 'FORK',
#  'FRKS': 'FORKS',
#  'FRRY': 'FERRY',
#  'FRST': 'FOREST',
#  'FRT': 'FORT',
#  'FRWAY': 'FREEWAY',
#  'FRWY': 'FREEWAY',
#  'FRY': 'FERRY',
#  'FT': 'FORT',
#  'FWY': 'FREEWAY',
#  'GARDN': 'GARDEN',
#  'GATEWY': 'GATEWAY',
#  'GATWAY': 'GATEWAY',
#  'GDN': 'GARDEN',
#  'GDNS': 'GARDENS',
#  'GLN': 'GLEN',
#  'GLNS': 'GLENS',
#  'GRDEN': 'GARDEN',
#  'GRDN': 'GARDEN',
#  'GRDNS': 'GARDENS',
#  'GRN': 'GREEN',
#  'GRNS': 'GREENS',
#  'GROV': 'GROVE',
#  'GRV': 'GROVE',
#  'GRVS': 'GROVES',
#  'GTWAY': 'GATEWAY',
#  'GTWY': 'GATEWAY',
#  'HARB': 'HARBOR',
#  'HARBR': 'HARBOR',
#  'HBR': 'HARBOR',
#  'HBRS': 'HARBORS',
#  'HIGHWY': 'HIGHWAY',
#  'HIWAY': 'HIGHWAY',
#  'HIWY': 'HIGHWAY',
#  'HL': 'HILL',
#  'HLLW': 'HOLLOW',
#  'HLS': 'HILLS',
#  'HOLLOWS': 'HOLLOW',
#  'HOLW': 'HOLLOW',
#  'HOLWS': 'HOLLOW',
#  'HRBOR': 'HARBOR',
#  'HT': 'HEIGHTS',
#  'HTS': 'HEIGHTS',
#  'HVN': 'HAVEN',
#  'HWAY': 'HIGHWAY',
#  'HWY': 'HIGHWAY',
#  'INLT': 'INLET',
#  'IS': 'ISLAND',
#  'ISLES': 'ISLE',
#  'ISLND': 'ISLAND',
#  'ISLNDS': 'ISLANDS',
#  'ISS': 'ISLANDS',
#  'JCT': 'JUNCTION',
#  'JCTION': 'JUNCTION',
#  'JCTN': 'JUNCTION',
#  'JCTNS': 'JUNCTIONS',
#  'JCTS': 'JUNCTIONS',
#  'JUNCTN': 'JUNCTION',
#  'JUNCTON': 'JUNCTION',
#  'KNL': 'KNOLL',
#  'KNLS': 'KNOLLS',
#  'KNOL': 'KNOLL',
#  'KY': 'KEY',
#  'KYS': 'KEYS',
#  'LCK': 'LOCK',
#  'LCKS': 'LOCKS',
#  'LDG': 'LODGE',
#  'LDGE': 'LODGE',
#  'LF': 'LOAF',
#  'LGT': 'LIGHT',
#  'LGTS': 'LIGHTS',
#  'LK': 'LAKE',
#  'LKS': 'LAKES',
#  'LN': 'LANE',
#  'LNDG': 'LANDING',
#  'LNDNG': 'LANDING',
#  'LODG': 'LODGE',
#  'LOOPS': 'LOOP',
#  'MDW': 'MEADOWS',
#  'MDWS': 'MEADOWS',
#  'MEDOWS': 'MEADOWS',
#  'MISSN': 'MISSION',
#  'ML': 'MILL',
#  'MLS': 'MILLS',
#  'MNR': 'MANOR',
#  'MNRS': 'MANORS',
#  'MNT': 'MOUNT',
#  'MNTAIN': 'MOUNTAIN',
#  'MNTN': 'MOUNTAIN',
#  'MNTNS': 'MOUNTAINS',
#  'MOUNTIN': 'MOUNTAIN',
#  'MSN': 'MISSION',
#  'MSSN': 'MISSION',
#  'MT': 'MOUNT',
#  'MTIN': 'MOUNTAIN',
#  'MTN': 'MOUNTAIN',
#  'MTNS': 'MOUNTAINS',
#  'MTWY': 'MOTORWAY',
#  'NCK': 'NECK',
#  'OPAS': 'OVERPASS',
#  'ORCH': 'ORCHARD',
#  'ORCHRD': 'ORCHARD',
#  'OVL': 'OVAL',
#  'PARK': 'PARKS',
#  'PARKWY': 'PARKWAY',
#  'PATHS': 'PATH',
#  'PIKES': 'PIKE',
#  'PKWAY': 'PARKWAY',
#  'PKWY': 'PARKWAYS',
#  'PKWYS': 'PARKWAYS',
#  'PKY': 'PARKWAY',
#  'PL': 'PLACE',
#  'PLN': 'PLAIN',
#  'PLNS': 'PLAINS',
#  'PLZ': 'PLAZA',
#  'PLZA': 'PLAZA',
#  'PNE': 'PINE',
#  'PNES': 'PINES',
#  'PR': 'PRAIRIE',
#  'PRK': 'PARK',
#  'PRR': 'PRAIRIE',
#  'PRT': 'PORT',
#  'PRTS': 'PORTS',
#  'PSGE': 'PASSAGE',
#  'PT': 'POINT',
#  'PTS': 'POINTS',
#  'RAD': 'RADIAL',
#  'RADIEL': 'RADIAL',
#  'RADL': 'RADIAL',
#  'RANCHES': 'RANCH',
#  'RD': 'ROAD',
#  'RDG': 'RIDGE',
#  'RDGE': 'RIDGE',
#  'RDGS': 'RIDGES',
#  'RDS': 'ROADS',
#  'RIV': 'RIVER',
#  'RIVR': 'RIVER',
#  'RNCH': 'RANCH',
#  'RNCHS': 'RANCH',
#  'RPD': 'RAPID',
#  'RPDS': 'RAPIDS',
#  'RST': 'REST',
#  'RTE': 'ROUTE',
#  'RVR': 'RIVER',
#  'SHL': 'SHOAL',
#  'SHLS': 'SHOALS',
#  'SHOAR': 'SHORE',
#  'SHOARS': 'SHORES',
#  'SHR': 'SHORE',
#  'SHRS': 'SHORES',
#  'SKWY': 'SKYWAY',
#  'SMT': 'SUMMIT',
#  'SPG': 'SPRING',
#  'SPGS': 'SPRINGS',
#  'SPNG': 'SPRING',
#  'SPNGS': 'SPRINGS',
#  'SPRNG': 'SPRING',
#  'SPRNGS': 'SPRINGS',
#  'SPUR': 'SPURS',
#  'SQ': 'SQUARE',
#  'SQR': 'SQUARE',
#  'SQRE': 'SQUARE',
#  'SQRS': 'SQUARES',
#  'SQS': 'SQUARES',
#  'SQU': 'SQUARE',
#  'ST': 'STREET',
#  'STA': 'STATION',
#  'STATN': 'STATION',
#  'STN': 'STATION',
#  'STR': 'STREET',
#  'STRA': 'STRAVENUE',
#  'STRAV': 'STRAVENUE',
#  'STRAVEN': 'STRAVENUE',
#  'STRAVN': 'STRAVENUE',
#  'STREME': 'STREAM',
#  'STRM': 'STREAM',
#  'STRT': 'STREET',
#  'STRVN': 'STRAVENUE',
#  'STRVNUE': 'STRAVENUE',
#  'STS': 'STREETS',
#  'SUMIT': 'SUMMIT',
#  'SUMITT': 'SUMMIT',
#  'TE': 'TERRACE',
#  'TER': 'TERRACE',
#  'TERR': 'TERRACE',
#  'TL': 'TRAIL',
#  'TPKE': 'TURNPIKE',
#  'TR': 'TRAIL',
#  'TRACES': 'TRACE',
#  'TRACKS': 'TRACK',
#  'TRAILS': 'TRAIL',
#  'TRAK': 'TRACK',
#  'TRCE': 'TRACE',
#  'TRFY': 'TRAFFICWAY',
#  'TRK': 'TRACK',
#  'TRKS': 'TRACK',
#  'TRL': 'TRAIL',
#  'TRLR': 'TRAILER',
#  'TRLRS': 'TRAILER',
#  'TRLS': 'TRAIL',
#  'TRNPK': 'TURNPIKE',
#  'TRWY': 'THROUGHWAY',
#  'TUNEL': 'TUNNEL',
#  'TUNL': 'TUNNEL',
#  'TUNLS': 'TUNNEL',
#  'TUNNELS': 'TUNNEL',
#  'TUNNL': 'TUNNEL',
#  'TURNPK': 'TURNPIKE',
#  'UN': 'UNION',
#  'UNS': 'UNIONS',
#  'UPAS': 'UNDERPASS',
#  'VALLY': 'VALLEY',
#  'VDCT': 'VIADUCT',
#  'VIA': 'VIADUCT',
#  'VIADCT': 'VIADUCT',
#  'VILL': 'VILLAGE',
#  'VILLAG': 'VILLAGE',
#  'VILLG': 'VILLAGE',
#  'VILLIAGE': 'VILLAGE',
#  'VIS': 'VISTA',
#  'VIST': 'VISTA',
#  'VL': 'VILLE',
#  'VLG': 'VILLAGE',
#  'VLGS': 'VILLAGES',
#  'VLLY': 'VALLEY',
#  'VLY': 'VALLEY',
#  'VLYS': 'VALLEYS',
#  'VST': 'VISTA',
#  'VSTA': 'VISTA',
#  'VW': 'VIEW',
#  'VWS': 'VIEWS',
#  'WA': 'WAY',
#  'WALK': 'WALKS',
#  'WL': 'WELL',
#  'WLS': 'WELLS',
#  'WY': 'WAY',
#  'XING': 'CROSSING',
#  'XRD': 'CROSSROAD',
#  'XRDS': 'CROSSROADS'}

# %%
### Conversion Functions ###

problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def completeStreetTypeAbbreviation(streetName):
    streetComponents = usaddress.parse(streetName)
    reconstructedStreet = []
    for streetComponent in streetComponents:
        if streetComponent[1] != "StreetNamePostType":
            reconstructedStreet.append(streetComponent[0])
        else:
            abbreviationToConvert = re.sub("[^A-Z]+", "", streetComponent[0].upper()) #convert to upper case and remove nonalpha chars
            reconstructedStreet.append(streetConversionMap.get(abbreviationToConvert, streetComponent[0]).capitalize())
    return " ".join(reconstructedStreet)

#The heavy lifter. This function takes a raw OSM XML element and converts it to a json object matching the data model.
def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way":
        node = {
            "id" : element.get("id"),
            "type" : element.tag,
            "visible" : element.get("visible"),
            "created" : {
                "version" : element.get("version"),
                "changeset" : element.get("changeset"),
                "timestamp" : element.get("timestamp"),
                "user" : element.get("user"),
                "uid" : element.get("uid")
            }
        }
        
        address = {}
        is_in = {}
        for tagEl in element.iter("tag"):
            if problemchars.match(tagEl.get("k")):          #Remove problematic attributes
                continue
            elif tagEl.get("k").startswith("addr:"):        #Structure address attribute based on data model
                components = tagEl.get("k").split(":")
                if len(components) == 2:
                    if (components[1] == "street"):
                        address[components[1]] = completeStreetTypeAbbreviation(tagEl.get("v"))
                    else:
                        address[components[1]] = tagEl.get("v")
            elif tagEl.get("k").startswith("is_in:"):        #Structure is_in attribute based on data model
                components = tagEl.get("k").split(":")
                if len(components) == 2:
                    is_in[components[1]] = tagEl.get("v")
            elif "phone" in tagEl.get("k").lower():         #Structure phone attribute based on data model
                npa, nxx, xxxx, phoneNumber = None, None, None, tagEl.get("v").strip()
                if phoneNumber.startswith("1"):
                    phoneNumber = phoneNumber[1:]
                elif phoneNumber.startswith("+1"):
                    phoneNumber = phoneNumber[2:]
                phoneNumberSections = re.findall(r'\d+', phoneNumber)
                if len(phoneNumberSections) == 3:
                    npa = phoneNumberSections[0]
                    nxx = phoneNumberSections[1]
                    xxxx = phoneNumberSections[2]
                elif len(phoneNumberSections) == 1 and len(phoneNumberSections[0]) == 10:
                    npa = phoneNumberSections[0][:3]
                    nxx = phoneNumberSections[0][3:6]
                    xxxx = phoneNumberSections[0][6:]
                if npa is not None and nxx is not None and xxxx is not None:
                    node["phone"] = {"npa": npa, "nxx": nxx, "xxxx": xxxx}
            else:
                tagKey = tagEl.get("k").replace(".", "")
                if (tagKey.startswith("$")):
                    tagKey = tagKey[1:]
                node[tagKey] = tagEl.get("v")
        
        node_refs = []
        for ndEl in element.iter("nd"):
            node_refs.append(ndEl.get("ref"))
            
        if len(address.keys()) > 0:
            node["address"] = address
            
        if len(is_in.keys()) > 0:
            node["is_in"] = is_in
            
        if len(node_refs) > 0:
            node["node_refs"] = node_refs
            
        if element.get("lat") is not None and element.get("lon") is not None:
            node["pos"] = [ float(element.get("lat")), float(element.get("lon")) ]
                
        return node
    else:
        return None

# %%
### Testing the Street Name Conversion ###
count = 0
for event, elem in ET.iterparse('los-angeles_california.osm', events=("start",)):
    if elem.tag == "node":
        for tag in elem.iter("tag"):
            if is_street_name(tag):
                print shape_element(elem)
                count += 1
    if count > 10:
        break
    elem.clear()
# Out:
# {'visible': None, 'created': {'uid': '1330847', 'changeset': '29169942', 'version': '4', 'user': 'TheDutchMan13', 'timestamp': '2015-03-01T04:53:03Z'}, 'pos': [33.3977365, -117.1701879], 'source': 'SanGIS Addresses Public Domain (http://www.sangis.org/)', 'address': {'city': 'San Diego', 'street': 'Rainbow Glen Road', 'housenumber': '2319', 'postcode': '92028', 'country': 'US'}, 'type': 'node', 'id': '49783403', 'is_in': {'city': 'San Diego', 'state': 'California', 'state_code': 'CA', 'country_code': 'US', 'country': 'United States of America'}}
# {'created': {'uid': '36038', 'changeset': '3293054', 'version': '3', 'user': 'DialH', 'timestamp': '2009-12-05T03:26:27Z'}, 'pos': [33.7369729, -117.9425644], 'visible': None, 'address': {'street': 'Kedge Avenue', 'housenumber': '10691'}, 'type': 'node', 'id': '281222596'}
# {'created': {'uid': '36038', 'changeset': '3293054', 'version': '3', 'user': 'DialH', 'timestamp': '2009-12-05T03:26:26Z'}, 'pos': [33.7369729, -117.9423584], 'visible': None, 'address': {'street': 'Kedge Avenue', 'housenumber': '10701'}, 'type': 'node', 'id': '281222682'}
# {'created': {'uid': '36038', 'changeset': '3293054', 'version': '3', 'user': 'DialH', 'timestamp': '2009-12-05T03:26:26Z'}, 'pos': [33.7369729, -117.942144], 'visible': None, 'address': {'street': 'Kedge Avenue', 'housenumber': '10711'}, 'type': 'node', 'id': '281222780'}

# %%
### Exploring the Data: `Way` Tags
count = 0
for event, elem in ET.iterparse('los-angeles_california.osm', events=("start",)):
    if elem.tag == "way":
        print shape_element(elem)
        count += 1
    if count > 10:
        break
    elem.clear()
# Out:
# {'old_ref': 'US 6;US 99', 'maxspeed': '65 mph', 'lanes': '6', 'name': 'Golden State Freeway', 'created': {'uid': '318696', 'changeset': '25524979', 'version': '54', 'user': 'n76', 'timestamp': '2014-09-18T17:06:21Z'}, 'hgv': 'designated', 'type': 'way', 'surface': 'paved', 'maxspeed:trailer': '55 mph', 'visible': None, 'node_refs': ['297523835', '364042999'], 'maxspeed:hgv': '55 mph', 'oneway': 'yes', 'bicycle': 'no', 'ref': 'I 5', 'id': '2417713', 'highway': 'motorway'}
# {'node_refs': ['598686507', '1377652371', '1377652375', '268525224', '268525223', '268525222', '268525221', '268525220', '1377652376', '1377652350', '1377652337'], 'name': 'Palm Avenue', 'created': {'uid': '262151', 'changeset': '12840540', 'version': '9', 'user': 'ToeBee', 'timestamp': '2012-08-24T05:54:50Z'}, 'visible': None, 'oneway': 'yes', 'type': 'way', 'id': '2430283', 'highway': 'tertiary'}
# {'maxspeed': '45 mph', 'node_refs': ['26850959', '268523183', '268523191', '569423515', '268523192', '268523186', '268523187', '268523180', '589526170', '122556342', '268522360', '268522361', '268522362', '268522363', '268522364', '268522365', '268522366', '268522367', '268522368', '268522369', '268522370', '268522371', '268522372', '268522373', '26848236', '268522419', '26848243', '598450810', '29526108', '598450815', '598450819', '26848255', '598450824', '29526109', '598450828', '598450830', '598450831', '598450832', '1858023407', '1858023410', '26848267', '373499051', '2256668508', '373499015', '26849775'], 'name': 'Huntington Drive', 'created': {'uid': '296869', 'changeset': '29669857', 'version': '21', 'user': 'Zian Choy', 'timestamp': '2015-03-23T02:48:15Z'}, 'source:maxspeed': 'sign', 'visible': None, 'source': 'survey;image;usgs_imagery', 'oneway': 'yes', 'source_ref': 'AM909_DSCR9668', 'type': 'way', 'id': '2430285', 'highway': 'primary', 'alt_name': 'Huntington Dr'}
# {'lanes': '4', 'name': 'Daly Street', 'created': {'uid': '977071', 'changeset': '32556573', 'version': '20', 'user': 'nathansnider', 'timestamp': '2015-07-11T01:14:53Z'}, 'visible': None, 'source': 'survey;image;usgs_imagery', 'node_refs': ['14798411', '364613612', '29526121', '3645297882', '16588311', '3645297874', '123428076', '3645297884', '122563307', '123428072', '21150970', '76413061', '364613903', '14941693', '1994529760', '3627346156', '38504727', '911278865', '1884813426', '911278973', '319882805'], 'old_ref:legislative': '4', 'type': 'way', 'id': '3126775', 'highway': 'primary', 'source_ref': 'AM909_DSCR9626'}
# {'odbl': 'clean', 'node_refs': ['178795499', '569423960', '552472995', '178795509', '26850959'], 'name': 'Fair Oaks Avenue', 'created': {'uid': '82317', 'changeset': '11429115', 'version': '14', 'user': 'AM909', 'timestamp': '2012-04-27T00:47:05Z'}, 'hgv': 'designated', 'visible': None, 'source': 'usgs_imagery;survey;image', 'oneway': 'yes', 'type': 'way', 'id': '3127999', 'highway': 'primary', 'source_ref': 'AM909_DSCU3203'}

# %%
### SETUP MONGO DATABASE AND COLLECTION ###
client = MongoClient()
db = client.la_osm
nodes = db.nodes
ways = db.ways

# %%
### INSERT DATA INTO NODES COLLECTION ###
for event, elem in ET.iterparse('los-angeles_california.osm', events=("start",)):
    if elem.tag == "node":
        nodes.insert_one(shape_element(elem))
    elem.clear()

# %%
### INSERT DATA INTO WAYS COLLECTION ###
for event, elem in ET.iterparse('los-angeles_california.osm', events=("start",)):
    if elem.tag == "way":
        ways.insert_one(shape_element(elem))
    elem.clear()

# %%
### REMOVE ALL DATA FROM NODES COLLECTION ###
nodes.drop()

# %%
### REMOVE ALL DATA FROM WAYS COLLECTION ###
ways.drop()

# %%
### Collection Sizes ###
print nodes.count()
print ways.count()
# Out:
# 5247813
# 562383

# %%
### Exploring the Data from the Mongo DB
for node in nodes.find({"address.city":{"$exists":1}}).limit(10):
    print node
# Out:
# {u'visible': None, u'created': {u'changeset': u'29169942', u'version': u'4', u'uid': u'1330847', u'timestamp': u'2015-03-01T04:53:03Z', u'user': u'TheDutchMan13'}, u'pos': [33.3977365, -117.1701879], u'source': u'SanGIS Addresses Public Domain (http://www.sangis.org/)', u'address': {u'city': u'San Diego', u'street': u'Rainbow Glen Road', u'housenumber': u'2319', u'postcode': u'92028', u'country': u'US'}, u'_id': ObjectId('55fdae39790c169b10077e59'), u'type': u'node', u'id': u'49783403', u'is_in': {u'city': u'San Diego', u'state': u'California', u'state_code': u'CA', u'country_code': u'US', u'country': u'United States of America'}}
# {u'created': {u'changeset': u'3603434', u'version': u'4', u'uid': u'147510', u'timestamp': u'2010-01-12T14:26:51Z', u'user': u'woodpeck_fixbot'}, u'pos': [34.2640642, -118.5486764], u'visible': None, u'address': {u'city': u'tu'}, u'_id': ObjectId('55fdaf73790c169b1013a578'), u'type': u'node', u'id': u'122978744'}
# {u'created': {u'changeset': u'3603434', u'version': u'4', u'uid': u'147510', u'timestamp': u'2010-01-12T14:29:19Z', u'user': u'woodpeck_fixbot'}, u'pos': [34.2592547, -118.5500582], u'visible': None, u'address': {u'city': u'tu'}, u'_id': ObjectId('55fdaf89790c169b101488dd'), u'type': u'node', u'id': u'123154695'}
# {u'created': {u'changeset': u'3610130', u'version': u'4', u'uid': u'147510', u'timestamp': u'2010-01-13T14:09:22Z', u'user': u'woodpeck_fixbot'}, u'pos': [34.264803, -118.5878175], u'visible': None, u'address': {u'city': u'tu'}, u'_id': ObjectId('55fdaf91790c169b1014d509'), u'type': u'node', u'id': u'123281335'}
# {u'created': {u'changeset': u'3293054', u'version': u'4', u'uid': u'36038', u'timestamp': u'2009-12-05T03:26:28Z', u'user': u'DialH'}, u'pos': [33.7370092, -117.94368], u'visible': None, u'address': {u'city': u'Garden Grove', u'street': u'Kedge Avenue', u'housenumber': u'10651', u'postcode': u'92843'}, u'_id': ObjectId('55fdafba790c169b10167f37'), u'type': u'node', u'id': u'281223568'}

# %%
### Sort Cities by Count, Descending ###
for result in nodes.aggregate([{"$match":{"address.city":{"$exists":1}}}, {"$group":{"_id":"$address.city", "count":{"$sum":1}}}, {"$sort":{"count":-1}}]):
    print result
# Out:
# {u'count': 14016, u'_id': u'San Diego'}
# {u'count': 11623, u'_id': u'Lake Forest'}
# {u'count': 10587, u'_id': u'Irvine'}
# {u'count': 7041, u'_id': u'Norco'}
# {u'count': 1442, u'_id': u'Trabuco Canyon'}
# {u'count': 727, u'_id': u'Corona'}
# {u'count': 444, u'_id': u'Tustin'}
# {u'count': 441, u'_id': u'Chino'}
# {u'count': 423, u'_id': u'San Clemente'}
# {u'count': 404, u'_id': u'Rialto'}
# {u'count': 398, u'_id': u'Claremont'}
# {u'count': 395, u'_id': u'Ontario'}
# {u'count': 388, u'_id': u'Los Angeles'}
# {u'count': 322, u'_id': u'Upland'}
# {u'count': 284, u'_id': u'Yucaipa'}
# {u'count': 247, u'_id': u'Mira Loma'}
# {u'count': 169, u'_id': u'Alta Loma'}
# {u'count': 166, u'_id': u'Rancho Cucamonga'}
# {u'count': 159, u'_id': u'Foothill Ranch'}
# {u'count': 155, u'_id': u'san gabriel'}
# {u'count': 143, u'_id': u'Wildomar'}
# {u'count': 140, u'_id': u'Mission Viejo'}
# {u'count': 140, u'_id': u'Perris'}
# {u'count': 139, u'_id': u'Pasadena'}
# {u'count': 129, u'_id': u'San Gabriel'}
# {u'count': 93, u'_id': u'Ventura, California'}
# {u'count': 91, u'_id': u'Yorba Linda'}
# {u'count': 90, u'_id': u'Malibu'}
# {u'count': 71, u'_id': u'Monrovia'}
# {u'count': 64, u'_id': u'Riverside'}
# {u'count': 61, u'_id': u'Long Beach'}
# {u'count': 59, u'_id': u'Lakewood'}
# {u'count': 55, u'_id': u'Burbank'}
# {u'count': 54, u'_id': u'Beverly Hills'}
# {u'count': 49, u'_id': u'Arcadia'}
# {u'count': 45, u'_id': u'Newport Beach'}
# {u'count': 40, u'_id': u'Anaheim'}
# {u'count': 39, u'_id': u'Santa Monica'}
# {u'count': 39, u'_id': u'Laguna Niguel'}
# {u'count': 36, u'_id': u'Highland'}
# {u'count': 35, u'_id': u'Fontana'}
# {u'count': 33, u'_id': u'Redlands'}
# {u'count': 32, u'_id': u'Eastvale'}
# {u'count': 31, u'_id': u'Glendale'}
# {u'count': 30, u'_id': u'Santa Ana'}
# {u'count': 30, u'_id': u'Glendora'}
# {u'count': 29, u'_id': u'Ventura'}
# {u'count': 28, u'_id': u'Temecula'}
# {u'count': 27, u'_id': u'Alhambra'}
# {u'count': 27, u'_id': u'Topanga'}
# {u'count': 25, u'_id': u'Calabasas'}
# {u'count': 25, u'_id': u'Costa Mesa'}
# {u'count': 24, u'_id': u'Commerce'}
# {u'count': 23, u'_id': u'Silverado'}
# {u'count': 22, u'_id': u'Chino Hills'}
# {u'count': 21, u'_id': u'Culver City'}
# {u'count': 21, u'_id': u'San Juan Capistrano'}
# {u'count': 20, u'_id': u'Murrieta'}
# {u'count': 20, u'_id': u'Brea'}
# {u'count': 19, u'_id': u'Fallbrook'}
# {u'count': 18, u'_id': u'Hollywood'}
# {u'count': 16, u'_id': u'Crestline'}
# {u'count': 16, u'_id': u'Monterey Park'}
# {u'count': 16, u'_id': u'La Puente'}
# {u'count': 15, u'_id': u'Buena Park'}
# {u'count': 15, u'_id': u'Torrance'}
# {u'count': 15, u'_id': u'San Bernardino'}
# {u'count': 14, u'_id': u'El Monte'}
# {u'count': 14, u'_id': u'Lake Elsinore'}
# {u'count': 14, u'_id': u'Garden Grove'}
# {u'count': 13, u'_id': u'Rancho Santa Margarita'}
# {u'count': 13, u'_id': u'Oxnard'}
# {u'count': 12, u'_id': u'Fullerton'}
# {u'count': 12, u'_id': u'Thousand Oaks'}
# {u'count': 12, u'_id': u'Norwalk'}
# {u'count': 11, u'_id': u'Orange'}
# {u'count': 11, u'_id': u'Ladera Ranch'}
# {u'count': 11, u'_id': u'Marina Del Rey'}
# {u'count': 10, u'_id': u'Moreno Valley'}
# {u'count': 10, u'_id': u'Etiwanda'}
# {u'count': 10, u'_id': u'Oceanside'}
# {u'count': 10, u'_id': u'Montebello'}
# {u'count': 10, u'_id': u'Temple City'}
# {u'count': 9, u'_id': u'Big Bear Lake'}
# {u'count': 9, u'_id': u'La Palma'}
# {u'count': 9, u'_id': u'Van Nuys'}
# {u'count': 9, u'_id': u'Dana Point'}
# {u'count': 9, u'_id': u'Whittier'}
# {u'count': 9, u'_id': u'Santa Clarita'}
# {u'count': 9, u'_id': u'Huntington Beach'}
# {u'count': 8, u'_id': u'Pico Rivera'}
# {u'count': 8, u'_id': u'San Pedro'}
# {u'count': 8, u'_id': u'City of Industry'}
# {u'count': 8, u'_id': u'Simi Valley'}
# {u'count': 7, u'_id': u'Westminster'}
# {u'count': 7, u'_id': u'Corona Del Mar'}
# {u'count': 7, u'_id': u'Banning'}
# {u'count': 7, u'_id': u'Seal Beach'}
# {u'count': 7, u'_id': u'Cabazon'}
# {u'count': 7, u'_id': u'Laguna Beach'}
# {u'count': 7, u'_id': u'Cerritos'}
# {u'count': 7, u'_id': u'West Covina'}
# {u'count': 7, u'_id': u'Running Springs'}
# {u'count': 7, u'_id': u'West Hollywood'}
# {u'count': 6, u'_id': u'Sherman Oaks'}
# {u'count': 6, u'_id': u'Menifee'}
# {u'count': 6, u'_id': u'Camarillo'}
# {u'count': 6, u'_id': u'Carson'}
# {u'count': 6, u'_id': u'Agoura Hills'}
# {u'count': 6, u'_id': u'Manhattan Beach'}
# {u'count': 5, u'_id': u'Canoga Park'}
# {u'count': 5, u'_id': u'Big Bear City'}
# {u'count': 5, u'_id': u'Studio City'}
# {u'count': 5, u'_id': u'Grand Terrace'}
# {u'count': 5, u'_id': u'Cypress'}
# {u'count': 5, u'_id': u'Sun Valley'}
# {u'count': 5, u'_id': u'Sunset Beach'}
# {u'count': 5, u'_id': u'Winchester'}
# {u'count': 5, u'_id': u'Encino'}
# {u'count': 5, u'_id': u'El Segundo'}
# {u'count': 5, u'_id': u'Granada Hills'}
# {u'count': 4, u'_id': u'Hermosa Beach'}
# {u'count': 4, u'_id': u'Baldwin Park'}
# {u'count': 4, u'_id': u'Victorville'}
# {u'count': 4, u'_id': u'Hawthorne'}
# {u'count': 4, u'_id': u'Pala'}
# {u'count': 4, u'_id': u'Redondo Beach'}
# {u'count': 4, u'_id': u'Lake Arrowhead'}
# {u'count': 4, u'_id': u'North Hollywood'}
# {u'count': 4, u'_id': u'Laguna Hills'}
# {u'count': 4, u'_id': u'Angelus Oaks'}
# {u'count': 4, u'_id': u'Moorpark'}
# {u'count': 4, u'_id': u'South El Monte'}
# {u'count': 4, u'_id': u'tu'}
# {u'count': 4, u'_id': u'Aliso Viejo'}
# {u'count': 4, u'_id': u'Ranchos Palos Verdes'}
# {u'count': 4, u'_id': u'Rosemead'}
# {u'count': 3, u'_id': u'South San Gabriel'}
# {u'count': 3, u'_id': u'Tujunga'}
# {u'count': 3, u'_id': u'Blue Jay'}
# {u'count': 3, u'_id': u'Colton'}
# {u'count': 3, u'_id': u'Marina del Rey'}
# {u'count': 3, u'_id': u'Newbury Park'}
# {u'count': 3, u'_id': u'Compton'}
# {u'count': 3, u'_id': u'Venice'}
# {u'count': 3, u'_id': u'Altadena'}
# {u'count': 3, u'_id': u'Pomona'}
# {u'count': 3, u'_id': u'Westlake Village'}
# {u'count': 3, u'_id': u'Hemet'}
# {u'count': 3, u'_id': u'Castaic'}
# {u'count': 3, u'_id': u'San Dimas'}
# {u'count': 3, u'_id': u'Playa Vista'}
# {u'count': 3, u'_id': u'Wilmington'}
# {u'count': 2, u'_id': u'Rolling Hills Estates'}
# {u'count': 2, u'_id': u'Mt. Baldy'}
# {u'count': 2, u'_id': u'Phelan'}
# {u'count': 2, u'_id': u'ALHAMBRA'}
# {u'count': 2, u'_id': u'Stevenson Ranch'}
# {u'count': 2, u'_id': u'Santa Paula'}
# {u'count': 2, u'_id': u'North Hollywood,CA'}
# {u'count': 2, u'_id': u'Duarte'}
# {u'count': 2, u'_id': u'Marina Del Rey CA'}
# {u'count': 2, u'_id': u'Fawnskin'}
# {u'count': 2, u'_id': u'Apple Valley'}
# {u'count': 2, u'_id': u'La Mirada'}
# {u'count': 2, u'_id': u'Oak Park'}
# {u'count': 2, u'_id': u'Sylmar'}
# {u'count': 2, u'_id': u'Avalon'}
# {u'count': 2, u'_id': u'Bonsall'}
# {u'count': 2, u'_id': u'Woodland Hills'}
# {u'count': 2, u'_id': u'Port Hueneme'}
# {u'count': 2, u'_id': u'Hesperia'}
# {u'count': 2, u'_id': u'La Ca\xf1ada Flintridge'}
# {u'count': 2, u'_id': u'Twin Peaks'}
# {u'count': 2, u'_id': u'Stanton'}
# {u'count': 2, u'_id': u'South Pasadena'}
# {u'count': 2, u'_id': u'Gardena'}
# {u'count': 2, u'_id': u'Sierra Madre'}
# {u'count': 2, u'_id': u'Montclair'}
# {u'count': 2, u'_id': u'Canyon Country'}
# {u'count': 2, u'_id': u'Valencia'}
# {u'count': 1, u'_id': u'Newhall'}
# {u'count': 1, u'_id': u'Diamond Bar'}
# {u'count': 1, u'_id': u'Bell Gardens'}
# {u'count': 1, u'_id': u'Palmdale'}
# {u'count': 1, u'_id': u'6447'}
# {u'count': 1, u'_id': u'Tarzana'}
# {u'count': 1, u'_id': u'Big Bear'}
# {u'count': 1, u'_id': u'Laguna Woods'}
# {u'count': 1, u'_id': u'garden grove'}
# {u'count': 1, u'_id': u'crestline'}
# {u'count': 1, u'_id': u'winnetka'}
# {u'count': 1, u'_id': u'Jurupa Valley, Ca.'}
# {u'count': 1, u'_id': u'Avalon, CA'}
# {u'count': 1, u'_id': u'Encino, CA'}
# {u'count': 1, u'_id': u'Harbor City'}
# {u'count': 1, u'_id': u'Baldwin Park (City of)'}
# {u'count': 1, u'_id': u'Marina del Ray'}
# {u'count': 1, u'_id': u'Bell'}
# {u'count': 1, u'_id': u'91041'}
# {u'count': 1, u'_id': u'Downey'}
# {u'count': 1, u'_id': u'Canyon Lake'}
# {u'count': 1, u'_id': u'Signal Hill'}
# {u'count': 1, u'_id': u'Camp Pendleton'}
# {u'count': 1, u'_id': u'South Gate'}
# {u'count': 1, u'_id': u'Lawndale'}
# {u'count': 1, u'_id': u'lakewood'}
# {u'count': 1, u'_id': u'Los Angeles, CA'}
# {u'count': 1, u'_id': u'Cedar Glen'}
# {u'count': 1, u'_id': u'Newport Coast'}
# {u'count': 1, u'_id': u'San Fernando'}
# {u'count': 1, u'_id': u'Los Alamitos'}
# {u'count': 1, u'_id': u'Valley of Enchantment'}
# {u'count': 1, u'_id': u'Murrietta'}
# {u'count': 1, u'_id': u'Rancho Palos Verdes'}
# {u'count': 1, u'_id': u'San Jacinto'}
# {u'count': 1, u'_id': u'Walnut'}
# {u'count': 1, u'_id': u'Escondido'}
# {u'count': 1, u'_id': u'Fillmore'}
# {u'count': 1, u'_id': u'Bellflower'}
# {u'count': 1, u'_id': u'Lomita'}
# {u'count': 1, u'_id': u'los angeles'}
# {u'count': 1, u'_id': u'Dove Canyon'}
# {u'count': 1, u'_id': u'Calimesa'}
# {u'count': 1, u'_id': u'Santa Fe Springs'}
# {u'count': 1, u'_id': u'Covina'}
# {u'count': 1, u'_id': u'Rancho Santa margarita'}
# {u'count': 1, u'_id': u'La Verne'}
# {u'count': 1, u'_id': u'Colton, CA'}
# {u'count': 1, u'_id': u'Inglewood'}
# {u'count': 1, u'_id': u'Palomar Mountain'}
# {u'count': 1, u'_id': u'santa Monica'}
# {u'count': 1, u'_id': u'Somis'}
# {u'count': 1, u'_id': u'Placentia'}
# {u'count': 1, u'_id': u'Terminal Island'}
# {u'count': 1, u'_id': u'rancho Cucamonga'}
# {u'count': 1, u'_id': u'Los Angeles Ca'}
# {u'count': 1, u'_id': u'Ventura County'}
# {u'count': 1, u'_id': u'Mar Vista'}
# {u'count': 1, u'_id': u'Cayon Country'}
# {u'count': 1, u'_id': u'Oak View'}
# {u'count': 1, u'_id': u'North Hills'}
# {u'count': 1, u'_id': u'long Beach'}
# {u'count': 1, u'_id': u'Temecula, Ca'}
# {u'count': 1, u'_id': u'Sunland'}
# {u'count': 1, u'_id': u'Piru'}
# {u'count': 1, u'_id': u'Phillips Ranch'}
# {u'count': 1, u'_id': u'Sun valley'}
# {u'count': 1, u'_id': u'Beaumont'}
# {u'count': 1, u'_id': u'La Habra'}
# {u'count': 1, u'_id': u'Padadena'}
# {u'count': 1, u'_id': u'West Hills'}
# {u'count': 1, u'_id': u'Hollywood, Los Angeles'}
# {u'count': 1, u'_id': u'Capistrano Beach'}
# {u'count': 1, u'_id': u'Valley Village'}
# {u'count': 1, u'_id': u'Anahiem'}
# {u'count': 1, u'_id': u'fullerton'}
# {u'count': 1, u'_id': u'Cyprus'}
# {u'count': 1, u'_id': u'Simi Valle'}
# {u'count': 1, u'_id': u'Irwindale'}
# {u'count': 1, u'_id': u'La Canada'}
# {u'count': 1, u'_id': u'West Los Angeles'}
# {u'count': 1, u'_id': u'Ojai'}
# {u'count': 1, u'_id': u'Brandeis'}
# {u'count': 1, u'_id': u'Lynwood'}
# {u'count': 1, u'_id': u'Clemente'}
# {u'count': 1, u'_id': u'Loma Linda'}
# {u'count': 1, u'_id': u'Venice CA'}

# %%
### Exploring the Data: Pasadena Amenities
for result in nodes.find({"address.city":"Pasadena"}):
    print result.get("name")
# Out:
# Shumei America National Center
# The Langham Huntington
# The Hat
# Ralph's
# Laemmle's Pasadena 7
# None
# Bank of America
# Nikka Fish & Grill
# None
# None
# None
# Pampa Furniture
# Barney's Beanery
# Beckham Grill
# Chipotle Mexican Grill
# Courtyard Marriot
# Du-par’s
# Blaze Pizza
# Celestino
# Starbucks
# Ross dress for less
# Jacob Maarse Florist
# Sport Clips
# Einstein Bros Bagels
# Jamba Juice
# Float
# Jameson Brown
# Fish Dish
# Jersey Mike's Subs
# Cafe 140 South
# Wine Bar
# Lemonade
# Wahoo's Fish Taco
# A'Float Sushi
# Connectionz Computer Repair
# Aramus Realty
# Neighborhood Unitarian Universalist Church
# eCivis Inc
# Slater's 50/50
# Half and Half Tea House (Express)
# Sahara
# Whole Foods
# Pasadena Handyman
# Congregation Ale House
# Color Me Mine
# ConfeXion Cupcakes
# Lineage Performing Arts Center
# Lime Twig Group
# Union Salon
# Anthroposophical Society in America
# Bang & Olufsen
# Gonzalez Goodale Architects
# Heart and Sole
# Pasadena Elite Fitness
# Tangles Salon
# Harmony Nail & Threading Salon
# Eileen Fisher
# Joie Pasadena
# LATHER
# Eastern Oriental Rugs
# H&R Block
# Happy Feet Massage
# Industrial Toys LLC
# O2 Sushi pasadena
# Prestige Jewelry
# Tiffany's Coffee
# URB-E - Pasadena
# Vinita's Beauty & Threading Studio
# Yummy Cupcakes Pasadena
# Bank of America
# Beany's Cafe
# Citibank
# Community Bank
# Linden Optometry, A P.C.
# Messerian Oriental Rugs
# Sotheby's International Realty, Inc.
# The Factory Studio
# US Post Office
# Bank of the West
# Le Cordon Bleu College of Culinary Arts
# Roy's Pasadena
# Settebello Pizzeria Napoletana
# Tender Greens Pasadena
# Bua Na Thai Cuisine
# Monopole Wine
# Pasadena Dentistry
# Planet Beach
# Takuya Japanese Restaurant
# U.S. Bank
# Vroman's Bookstore
# Yahaira's Cafe
# redwhite+bluezz
# Angels School Supply
# La Fiesta Grande
# La Soie Bridal
# Nouri Rugs
# Pasadena Nails & Skin Care!
# Sitar Indian Cuisine
# Urth Caffé - Pasadena
# Nine & Nine Thai Kitchen
# eat ME up!
# Bentley Pasadena
# Rusnak Maserati of Pasadena
# Rusnak/Pasadena Audi
# Rusnak/Pasadena Jaguar
# Rusnak/Pasadena Porsche
# Huntington Rare Coins & Precious Metals
# JRR Design Firm
# Norbert Rug Gallery & Associates
# Amadeus Spa
# Relax The Back
# Tarantino's Pizzeria
# Which Wich
# First Financial Credit Union
# Mattress City
# Simplicity Bank
# Verizon Wireless Corner
# Aaron Brothers Art & Framing
# Pet Food Express
# Sit 'n Sleep
# Trattoria Neapolis
# Right Start
# Verizon Wireless
# Custom Comfort Mattress
# Draper's & Damon's
# Men's Wearhouse
# Pacific Sales Kitchen, Bath & Electronics
# Pier 1 Imports
# None
# The Blind Donkey
# Dog Haus Biergarten
# Valvoline Instant Oil Change
# Sprouts Farmers Market
# The Habit
# See's Candies Chocolate Shop
# Cost Plus World Market
# 7-11
# Pasadena Senior Center
# Ecumenical Council of Pasadena Area Congregations - Food Bank

# %%
### Exploring the Data: Biggest Contributor to Nodes
nodes.aggregate([{"$group":{"_id":"$created.user", "count":{"$sum":1}}}, {"$sort":{"count":-1}}, {"$limit":1}]).next()
# Out:
# {u'_id': u'woodpeck_fixbot', u'count': 546730}

# %%
### Exploring the Data: Ways with Names
for way in ways.find({"name":{"$exists":1}}).limit(10):
    print way
# Out:
# {u'old_ref': u'US 6;US 99', u'maxspeed': u'65 mph', u'lanes': u'6', u'name': u'Golden State Freeway', u'bicycle': u'no', u'created': {u'changeset': u'25524979', u'version': u'54', u'uid': u'318696', u'timestamp': u'2014-09-18T17:06:21Z', u'user': u'n76'}, u'hgv': u'designated', u'ref': u'I 5', u'surface': u'paved', u'visible': None, u'node_refs': [u'297523835', u'364042999'], u'highway': u'motorway', u'oneway': u'yes', u'maxspeed:trailer': u'55 mph', u'_id': ObjectId('55fdfe84790c169b105a9ed7'), u'type': u'way', u'id': u'2417713', u'maxspeed:hgv': u'55 mph'}
# {u'node_refs': [u'598686507', u'1377652371', u'1377652375', u'268525224', u'268525223', u'268525222', u'268525221', u'268525220', u'1377652376', u'1377652350', u'1377652337'], u'name': u'Palm Avenue', u'created': {u'changeset': u'12840540', u'version': u'9', u'uid': u'262151', u'timestamp': u'2012-08-24T05:54:50Z', u'user': u'ToeBee'}, u'visible': None, u'oneway': u'yes', u'_id': ObjectId('55fdfe84790c169b105a9ed8'), u'type': u'way', u'id': u'2430283', u'highway': u'tertiary'}
# {u'maxspeed': u'35 mph', u'lanes': u'5', u'name': u'North Broadway', u'created': {u'changeset': u'15659696', u'version': u'25', u'uid': u'977071', u'timestamp': u'2013-04-08T21:07:55Z', u'user': u'nathansnider'}, u'visible': None, u'source': u'survey;image;usgs_imagery', u'node_refs': [u'14854412', u'2258860933', u'2258860802', u'2258860790', u'122727572', u'1840702743', u'122909160'], u'_id': ObjectId('55fdfe84790c169b105a9ede'), u'type': u'way', u'id': u'3126730', u'highway': u'primary', u'source_ref': u'AM909_DSCR9625;AM909_DSCR9651'}
# {u'maxspeed': u'45 mph', u'lanes': u'2', u'name': u'Mission Road', u'created': {u'changeset': u'29669857', u'version': u'15', u'uid': u'296869', u'timestamp': u'2015-03-23T02:48:17Z', u'user': u'Zian Choy'}, u'source:maxspeed': u'sign', u'visible': None, u'source': u'survey;image;usgs_imagery', u'oneway': u'yes', u'node_refs': [u'122697366', u'614131018', u'72510199'], u'_id': ObjectId('55fdfe84790c169b105a9edf'), u'type': u'way', u'id': u'3126731', u'highway': u'primary', u'source_ref': u'AM909_DSCR9651'}
# {u'old_ref:legislative': u'4', u'lanes': u'4', u'name': u'Daly Street', u'visible': None, u'created': {u'changeset': u'32556573', u'version': u'20', u'uid': u'977071', u'timestamp': u'2015-07-11T01:14:53Z', u'user': u'nathansnider'}, u'source': u'survey;image;usgs_imagery', u'node_refs': [u'14798411', u'364613612', u'29526121', u'3645297882', u'16588311', u'3645297874', u'123428076', u'3645297884', u'122563307', u'123428072', u'21150970', u'76413061', u'364613903', u'14941693', u'1994529760', u'3627346156', u'38504727', u'911278865', u'1884813426', u'911278973', u'319882805'], u'_id': ObjectId('55fdfe84790c169b105a9ee0'), u'type': u'way', u'id': u'3126775', u'highway': u'primary', u'source_ref': u'AM909_DSCR9626'}

# %%
### Exploring the Data: Way with the Most Refs
longestNodeRefsArray = ways.aggregate([{"$project": {"_id":"$_id", "node_refs":"$node_refs", "size": {"$size":{ "$ifNull": [ "$node_refs", [] ] }}}}, {"$sort":{"size":-1}}, {"$limit": 1}]).next()
ways.find_one({"_id":longestNodeRefsArray["_id"]})
# Out:
# {u'_id': ObjectId('55fdfed1790c169b105bb831'),
#  u'created': {u'changeset': u'5734395',
#   u'timestamp': u'2010-09-09T16:59:54Z',
#   u'uid': u'82317',
#   u'user': u'AM909',
#   u'version': u'6'},
#  u'id': u'10743743',
#  u'node_refs': [u'95590278',
#   u'95692955',
#   u'95692956',
#   u'95692957',
#   u'95692958',
#   u'95692959',
#   u'95692960',
#   u'95692961',
#   u'95692962',
#   u'95692963',
#   u'95692964',
#   u'95692965',
#   u'95692966',
#   u'95692967',
#   u'95692968',
#   u'95692969',
#   u'95692970',
#   u'95692971',
#   u'95692972',
#   u'95692973',
#   u'95692974',
#   u'95692975',
#   u'95692976',
#   u'95692977',
#   u'95692978',
#   u'95692979',
#   u'95386816',
#   u'95692980',
#   u'95692981',
#   u'95692982',
#   u'95692983',
wayCount = ways.count()
print "Total Number of Nodes:\t\t", nodeCount
print "Total Number of Ways:\t\t", wayCount
print "Total Number of All Documents:\t", nodeCount + wayCount
print 

uniqueUsersInNodes = uniqueUsers(nodes)
uniqueUsersInWays = uniqueUsers(ways)
print "Unique Users in Nodes:\t\t", len(uniqueUsersInNodes)
print "Unique Users in Ways:\t\t", len(uniqueUsersInWays)
print "Unique Users in All Documents:\t", len(uniqueUsersInNodes | uniqueUsersInWays)
print
# Out:
# Total Number of Nodes:		5247813
# Total Number of Ways:		562383
# Total Number of All Documents:	5810196
#
# Unique Users in Nodes:		2628
# Unique Users in Ways:		1975
# Unique Users in All Documents:	2871

# %%
### Top Contributor Statistics ###
def topContributingUsers(limit, *collections):
    if limit <= 0:
        return None
    contributors = {}
    for collection in collections:
        for contributor in collection.aggregate([{"$group":{"_id":"$created.user", "count":{"$sum":1}}}]):
            contributionCount = contributors.get(contributor["_id"], 0) + contributor["count"]
            contributors[contributor["_id"]] = contributionCount
    return heapq.nlargest(limit, contributors.items(), lambda pair: pair[1])

topContributorLimit = 10
topContributorsInNodes = topContributingUsers(topContributorLimit, nodes)
topContributorsInWays = topContributingUsers(topContributorLimit, ways)
topContributorsInAllDocuments = topContributingUsers(topContributorLimit, nodes, ways)
print "Top {} Contributors in Nodes:".format(topContributorLimit)
print "".join(["{:<30}{:<10}({:.2%})\n".format(username, contributionCount, float(contributionCount) / nodeCount) for username, contributionCount in topContributorsInNodes])
print "Top {} Contributors in Ways:".format(topContributorLimitPerList)
print "".join(["{:<30}{:<10}({:.2%})\n".format(username, contributionCount, float(contributionCount) / wayCount) for username, contributionCount in topContributorsInWays])
print "Top {} Contributors in All Documents:".format(topContributorLimitPerList)
print "".join(["{:<30}{:<10}({:.2%})\n".format(username, contributionCount, float(contributionCount) / (nodeCount + wayCount)) for username, contributionCount in topContributorsInAllDocuments])
# Out:
# Top 10 Contributors in Nodes:
# woodpeck_fixbot               546730    (10.42%)
# The Temecula Mapper           452435    (8.62%)
# AM909                         429283    (8.18%)
# nmixter                       329645    (6.28%)
# Brian@Brea                    206737    (3.94%)
# Aaron Lidman                  154956    (2.95%)
# SJFriedl                      137614    (2.62%)
# Jon Schleuss                  132206    (2.52%)
# jerjozwik                     130263    (2.48%)
# mattmaxon                     116291    (2.22%)
#
# Top 10 Contributors in Ways:
# balrog-kun                    62022     (11.03%)
# The Temecula Mapper           39083     (6.95%)
# AM909                         33124     (5.89%)
# Aaron Lidman                  26817     (4.77%)
# Brian@Brea                    26430     (4.70%)
# SJFriedl                      17471     (3.11%)
# NE2                           11960     (2.13%)
# Jon Schleuss                  10677     (1.90%)
# DaveHansenTiger               10607     (1.89%)
# jerjozwik                     10292     (1.83%)
#
# Top 10 Contributors in All Documents:
# woodpeck_fixbot               546732    (9.41%)
# The Temecula Mapper           491518    (8.46%)
# AM909                         462407    (7.96%)
# nmixter                       330838    (5.69%)
# Brian@Brea                    233167    (4.01%)
# Aaron Lidman                  181773    (3.13%)
# SJFriedl                      155085    (2.67%)
# Jon Schleuss                  142883    (2.46%)
# jerjozwik                     140555    (2.42%)
# mattmaxon                     121211    (2.09%)

# %%
### Top Amenities Statistics ###
def topAmenities(limit, collection):
    return collection.aggregate([{"$match":{"amenity":{"$exists":1}}}, {"$group":{"_id":"$amenity","count":{"$sum":1}}}, {"$sort":{"count":-1}}, {"$limit":limit}])

def keyToTitle(key):
    return key.replace("_", " ").title()

topAmenitiesLimit = 10
topAmenitiesList = topAmenities(topAmenitiesLimit, nodes)
print "Top {} Amenity Types:".format(topAmenitiesLimit)
print "".join(["{:<30}{:<10}\n".format(keyToTitle(amenity["_id"]), amenity["count"]) for amenity in topAmenitiesList])
# Out:
# Top 10 Amenity Types:
# Place Of Worship              3788
# School                        3123
# Restaurant                    1725
# Fast Food                     1254
# Fuel                          745
# Cafe                          576
# Fountain                      493
# Parking                       490
# Toilets                       483
# Drinking Water                458

# %%
### Top Restaurant Statistics ###
def topCuisines(limit, collection):
    return collection.aggregate([{"$match":{"cuisine":{"$exists":1}, "amenity":"restaurant"}}, {"$group":{"_id":"$cuisine", "count":{"$sum":1}}}, {"$sort":{"count":-1}}, {"$limit":limit}])

def topRestaurants(limit, collection):
    return collection.aggregate([{"$match":{"name":{"$exists":1}, "amenity":"restaurant"}}, {"$group":{"_id":"$name", "cuisines":{"$push":"$cuisine"}, "count":{"$sum":1}}}, {"$sort":{"count":-1}}, {"$limit":limit}])

def keyToTitle(key):
    return key.replace("_", " ").title()

topCuisinesLimit = 15
topRestaurantsLimit = 20
topCuisinesList = topCuisines(topCuisinesLimit, nodes)
topRestaurantsList = topRestaurants(topRestaurantsLimit, nodes)
print "Top {} Cuisines:".format(topCuisinesLimit)
print "".join(["{:<30}{:<10}\n".format(keyToTitle(cuisine["_id"]), cuisine["count"]) for cuisine in topCuisinesList])
print "Top {} Restaurants:".format(topRestaurantsLimit)
print "".join(["{:<30}{:<10}({})\n".format(restaurant["_id"], restaurant["count"], ", ".join(set(map(keyToTitle, restaurant["cuisines"])))) for restaurant in topRestaurantsList])
# Out:
# Top 15 Cuisines:
# American                      155
# Mexican                       145
# Pizza                         84
# Italian                       67
# Chinese                       57
# Japanese                      47
# Thai                          41
# Burger                        40
# Sushi                         39
# Sandwich                      33
# Seafood                       24
# Steak House                   17
# Indian                        16
# Asian                         15
# Regional                      15
#
# Top 20 Restaurants:
# Denny's                       23        (American, Diner)
# Subway                        17        (Sandwich)
# IHOP                          15        (Breakfast, American, Pancake)
# Panda Express                 10        (American, Chinese)
# Chipotle                      9         (Mexican)
# Pizza Hut                     9         (Pizza)
# California Pizza Kitchen      9         (Pizza, Italian)
# Sizzler                       7         (American, Steak)
# Red Robin                     7         (Burger, American)
# Ruby's Diner                  7         (American)
# Cheesecake Factory            7         (American)
# Rubio's                       6         (Mexican)
# Chipotle Mexican Grill        5         (Mexican)
# Islands                       5         (Burger, American)
# Round Table Pizza             5         (Pizza)
# Corner Bakery                 5         (Chinese)
# Carrows                       5         (American)
# Olive Garden                  5         (Italian)
# Chili's                       4         ()
# BJ's                          4         (American)

# %%
### Number of In N Outs
len(list(nodes.aggregate([{"$match":{"name":"In N Out"}}])))
# Out:
# 2
